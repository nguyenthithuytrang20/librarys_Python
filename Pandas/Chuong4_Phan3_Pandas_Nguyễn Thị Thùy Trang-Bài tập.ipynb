# %% [markdown]
# <img src ='Pic\logo_CNTT.png' width='400px'>
# <div align="center">
# <h2> MÔN HỌC: KHOA HỌC DỮ LIỆU (7080509) </h2>
# </div>
#
# ---
# <center>
# <h1> CHƯƠNG 4: MỘT SỐ THƯ VIỆN QUAN TRỌNG CHO KHOA HỌC DỮ LIỆU - PHẦN 3 (PANDAS)</h1>
# </center>
#
# ---
#
# **NỘI DUNG BÀI HỌC:**
# 1. Giới thiệu Pandas
# 2. Tạo đối tượng cơ bản trong Pandas
#     * Series
#     * Dataframe
# 3. Đọc dữ liệu từ các nguồn khác nhau
# 4. Quan sát và truy xuất dữ liệu trong DataFrame
# 5. Replacing Values, Rename Columns
# 6. Lọc dữ liệu trong DataFrame
# 7. Xác định các tham số thống kê: Sum, Cumsum, Min, Max, Mean, Median, Std
# 8. Giá trị duy nhất (Unique)
#
# ---
# *Copyright: Nguyễn Thị Thùy Trang 2021050885 DCCTKTk65B

# %% [markdown]
# ## THỰC HÀNH SỐ 1
# ---
# **Yêu cầu 1.1: Học viên đọc dữ liệu dạng CSV lưu trong file csv_Data_Loan.csv với các tham số mặc định, cho biết các thông tin cơ bản của file**

# %%
#{HỌC VIÊN VIẾT CODE VÀO ĐÂY}
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

part_loan='Data/csv_Data_Loan.csv'
df_Loan=pd.read_csv(part_loan)

# Đọc số liệu ____.info()
df_Loan.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 113680 entries, 0 to 113679
# Data columns (total 8 columns):
#  #   Column          Non-Null Count   Dtype
# ---  ------          --------------   -----
#  0   loan_amnt       113680 non-null  int64
#  1   term            113680 non-null  object
#  2   int_rate        113680 non-null  float64
#  3   home_ownership  113680 non-null  object
#  4   annual_inc      113676 non-null  float64
#  5   purpose         113680 non-null  object
#  6   addr_state      113680 non-null  object
#  7   bad_loan        113680 non-null  int64
# dtypes: float64(2), int64(2), object(4)
# memory usage: 6.9+ MB

# %%
#Hiển thị 5 dòng đầu tiên
df_Loan.head()
# Out:
#    loan_amnt       term  int_rate home_ownership  annual_inc         purpose  \
# 0       5000  36 months     10.65           RENT     24000.0     credit_card
# 1       2500  60 months     15.27           RENT     30000.0             car
# 2       2400  36 months     15.96           RENT     12252.0  small_business
# 3      10000  36 months     13.49           RENT     49200.0           other
# 4       5000  36 months      7.90           RENT     36000.0         wedding
#
#   addr_state  bad_loan
# 0         AZ         0
# 1         GA         1
# 2         IL         0
# 3         CA         0
# 4         AZ         0

# %% [markdown]
# **Yêu cầu 1.2: Đọc dữ liệu từ file Data_Loan.CSV vào 2 biến DataFrame tương ứng**
# 1. df_number: Chỉ chứa các cột dữ liệu số
# 2. df_object: Chỉ chứa các cột dữ liệu Object

# %%
#{HỌC VIÊN VIẾT CODE VÀO ĐÂY}
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
print('Các cột dữ liệu số')
df_loan=pd.read_csv('Data/csv_Data_Loan.csv')
df_number=df_loan.loc[:,['loan_amnt','int_rate','annual_inc','annual_inc']]
df_number
# Out:
# Các cột dữ liệu số
#         loan_amnt  int_rate  annual_inc  annual_inc
# 0            5000     10.65     24000.0     24000.0
# 1            2500     15.27     30000.0     30000.0
# 2            2400     15.96     12252.0     12252.0
# 3           10000     13.49     49200.0     49200.0
# 4            5000      7.90     36000.0     36000.0
# ...           ...       ...         ...         ...
# 113675      15000     12.39     45000.0     45000.0
# 113676      20000     14.99     80000.0     80000.0
# 113677      12825     17.14     38000.0     38000.0
# 113678      27650     21.99     60000.0     60000.0
# 113679      17000     15.99     63078.0     63078.0
#
# [113680 rows x 4 columns]

# %%
print('các cột dữ liệu Object')
df_object=df_loan.loc[:,['term','home_ownership','purpose','addr_state']]
df_object
# Out:
# các cột dữ liệu Object
#              term home_ownership             purpose addr_state
# 0       36 months           RENT         credit_card         AZ
# 1       60 months           RENT                 car         GA
# 2       36 months           RENT      small_business         IL
# 3       36 months           RENT               other         CA
# 4       36 months           RENT             wedding         AZ
# ...           ...            ...                 ...        ...
# 113675  60 months       MORTGAGE         credit_card         OK
# 113676  36 months            OWN    home_improvement         VA
# 113677  36 months       MORTGAGE  debt_consolidation         TX
# 113678  60 months           RENT         credit_card         NY
# 113679  60 months       MORTGAGE  debt_consolidation         PA
#
# [113680 rows x 4 columns]

# %% [markdown]
# **Yêu cầu 1.3: Đọc dữ liệu nhiệt độ của 6 thành phố [Hà Nội, Vinh, Đà Nẵng, Nha Trang, TP Hồ Chí Minh, Cà Mau] từ file txt_Data_Temp.txt vào biến DataFrame tương ứng**

# %%
#{HỌC VIÊN VIẾT CODE VÀO ĐÂY}
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
df_temp=pd.DataFrame(pd.read_csv('Data/txt_Data_Temp.txt ',
                                 sep=' ',
                                 header=None,
                                 names=['Hà Nội', 'Vinh', 'Đà Nẵng', 'Nha Trang', 'TP Hồ Chí Minh', 'Cà Mau']))
df_temp
# Out:
#      Hà Nội   Vinh  Đà Nẵng  Nha Trang  TP Hồ Chí Minh  Cà Mau
# 0     25.65  24.79    24.01      25.06           25.48   24.97
# 1     25.31  24.21    24.02      24.93           25.16   24.83
# 2     25.05  23.73    23.89      24.79           24.80   24.55
# 3     24.79  23.36    23.83      24.84           24.74   24.48
# 4     24.59  23.05    23.69      24.82           24.80   24.38
# ..      ...    ...      ...        ...             ...     ...
# 187   26.56  24.92    24.10      26.11           25.56   26.43
# 188   25.69  24.77    23.76      25.97           25.23   25.88
# 189   24.81  24.47    23.40      25.86           25.05   25.29
# 190   23.97  24.22    22.95      25.74           24.92   24.87
# 191   22.84  23.99    22.59      25.50           24.77   24.57
#
# [192 rows x 6 columns]

# %% [markdown]
# ## THỰC HÀNH 3.2
# ---
# Yêu cầu: Học viên đọc dữ liệu dạng excel lưu trong file excel_Data_Movies.xls theo từng sheet

# %%
#{HỌC VIÊN VIẾT CODE Ở ĐÂY}
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
read_file=('Data/excel_Data_Movies.xls')
df_sheet1= pd.read_excel(read_file,
                        sheet_name='1900s')
df_sheet1
# Out:
#                                                   Title  Year  \
# 0     Intolerance: Love's Struggle Throughout the Ages   1916
# 1                       Over the Hill to the Poorhouse   1920
# 2                                       The Big Parade   1925
# 3                                           Metropolis   1927
# 4                                        Pandora's Box   1929
# ...                                                 ...   ...
# 1333                                  Twin Falls Idaho   1999
# 1334                     Universal Soldier: The Return   1999
# 1335                                     Varsity Blues   1999
# 1336                                    Wild Wild West   1999
# 1337                                    Wing Commander   1999
#
#                             Genres Language  Country Content Rating  Duration  \
# 0                Drama|History|War      NaN      USA      Not Rated       123
# 1                      Crime|Drama      NaN      USA            NaN       110
# 2                Drama|Romance|War      NaN      USA      Not Rated       151
# 3                     Drama|Sci-Fi   German  Germany      Not Rated       145
# 4              Crime|Drama|Romance   German  Germany      Not Rated       110
# ...                            ...      ...      ...            ...       ...
# 1333                         Drama  English      USA              R       111
# 1334                 Action|Sci-Fi  English      USA              R        83
# 1335    Comedy|Drama|Romance|Sport  English      USA              R       106
# 1336  Action|Comedy|Sci-Fi|Western  English      USA          PG-13       106
# 1337       Action|Adventure|Sci-Fi  English      USA          PG-13       100
#
#       Aspect Ratio       Budget  Gross Earnings  ... Facebook Likes - Actor 1  \
# 0             1.33     385907.0             NaN  ...                      436
# 1             1.33     100000.0       3000000.0  ...                        2
# 2             1.33     245000.0             NaN  ...                       81
# 3             1.33    6000000.0         26435.0  ...                      136
# 4             1.33          NaN          9950.0  ...                      426
# ...            ...          ...             ...  ...                      ...
# 1333          1.85     500000.0        985341.0  ...                      980
# 1334          1.85   24000000.0      10431220.0  ...                     2000
# 1335          1.85   16000000.0      52885587.0  ...                    23000
# 1336          1.85  170000000.0     113745408.0  ...                    10000
# 1337          2.35   30000000.0      11576087.0  ...                      811
#
#      Facebook Likes - Actor 2 Facebook Likes - Actor 3  \
# 0                          22                      9.0
# 1                           2                      0.0
# 2                          12                      6.0
# 3                          23                     18.0
# 4                          20                      3.0
# ...                       ...                      ...
# 1333                      505                    482.0
# 1334                      577                    485.0
# 1335                      255                     35.0
# 1336                     4000                    582.0
# 1337                      586                    362.0
#
#      Facebook Likes - cast Total  Facebook likes - Movie  \
# 0                            481                     691
# 1                              4                       0
# 2                            108                     226
# 3                            203                   12000
# 4                            455                     926
# ...                          ...                     ...
# 1333                        3166                     180
# 1334                        4024                     401
# 1335                       23369                       0
# 1336                       15870                       0
# 1337                        2497                     858
#
#       Facenumber in posters  User Votes  Reviews by Users  Reviews by Crtiics  \
# 0                         1       10718                88                69.0
# 1                         1           5                 1                 1.0
# 2                         0        4849                45                48.0
# 3                         1      111841               413               260.0
# 4                         1        7431                84                71.0
# ...                     ...         ...               ...                 ...
# 1333                      0        3479                87                54.0
# 1334                      0       24216               162                75.0
# 1335                      0       35312               267                67.0
# 1336                      2      129601               648                85.0
# 1337                      3       14747               338                85.0
#
#       IMDB Score
# 0            8.0
# 1            4.8
# 2            8.3
# 3            8.3
# 4            8.0
# ...          ...
# 1333         7.3
# 1334         4.1
# 1335         6.4
# 1336         4.8
# 1337         4.1
#
# [1338 rows x 25 columns]

# %%
read_file=('Data/excel_Data_Movies.xls')
df_sheet2=pd.read_excel(read_file,
                       sheet_name=1,
                       skiprows=3)
df_sheet2
# Out:
#                                   Title  Year  \
# 0                       102 Dalmatians   2000
# 1                              28 Days   2000
# 2                            3 Strikes   2000
# 3                             Aberdeen   2000
# 4                All the Pretty Horses   2000
# ...                                 ...   ...
# 2095          X-Men Origins: Wolverine   2009
# 2096                          Year One   2009
# 2097                   Youth in Revolt   2009
# 2098  ZMD: Zombies of Mass Destruction   2009
# 2099                        Zombieland   2009
#
#                                         Genres Language Country  \
# 0                      Adventure|Comedy|Family  English     USA
# 1                                 Comedy|Drama  English     USA
# 2                                       Comedy  English     USA
# 3                                        Drama  English      UK
# 4                        Drama|Romance|Western  English     USA
# ...                                        ...      ...     ...
# 2095  Action|Adventure|Fantasy|Sci-Fi|Thriller  English     USA
# 2096                          Adventure|Comedy  English     USA
# 2097                      Comedy|Drama|Romance  English     USA
# 2098                      Comedy|Horror|Sci-Fi  English     USA
# 2099            Adventure|Comedy|Horror|Sci-Fi  English     USA
#
#      Content Rating  Duration  Aspect Ratio       Budget  Gross Earnings  ...  \
# 0                 G     100.0          1.85   85000000.0      66941559.0  ...
# 1             PG-13     103.0          1.37   43000000.0      37035515.0  ...
# 2                 R      82.0          1.85    6000000.0       9821335.0  ...
# 3               NaN     106.0          1.85    6500000.0         64148.0  ...
# 4             PG-13     220.0          2.35   57000000.0      15527125.0  ...
# ...             ...       ...           ...          ...             ...  ...
# 2095          PG-13     119.0          2.35  150000000.0     179883016.0  ...
# 2096          PG-13     100.0          1.85   60000000.0      43337279.0  ...
# 2097              R      90.0          1.85   18000000.0      15281286.0  ...
# 2098              R      89.0          1.85     500000.0             NaN  ...
# 2099              R      88.0          2.35   23600000.0      75590286.0  ...
#
#      Facebook Likes - Actor 1 Facebook Likes - Actor 2  \
# 0                      2000.0                    795.0
# 1                     12000.0                  10000.0
# 2                       939.0                    706.0
# 3                       844.0                      2.0
# 4                     13000.0                    861.0
# ...                       ...                      ...
# 2095                  20000.0                  16000.0
# 2096                  10000.0                   1000.0
# 2097                  12000.0                    904.0
# 2098                    199.0                     37.0
# 2099                  15000.0                  13000.0
#
#      Facebook Likes - Actor 3 Facebook Likes - cast Total  \
# 0                       439.0                        4182
# 1                       664.0                       23864
# 2                       585.0                        3354
# 3                         0.0                         846
# 4                       820.0                       15006
# ...                       ...                         ...
# 2095                   2000.0                       40054
# 2096                    485.0                       12258
# 2097                    729.0                       16004
# 2098                     23.0                         292
# 2099                     11.0                       28011
#
#       Facebook likes - Movie  Facenumber in posters  User Votes  \
# 0                        372                      1       26413
# 1                          0                      1       34597
# 2                        118                      1        1415
# 3                        260                      0        2601
# 4                        652                      2       11388
# ...                      ...                    ...         ...
# 2095                       0                      0      361924
# 2096                       0                      2       76770
# 2097                       0                      2       64646
# 2098                       0                      0        3650
# 2099                   26000                      4      386217
#
#       Reviews by Users  Reviews by Crtiics  IMDB Score
# 0                 77.0                84.0         4.8
# 1                194.0               116.0         6.0
# 2                 10.0                22.0         4.0
# 3                 35.0                28.0         7.3
# 4                183.0                85.0         5.8
# ...                ...                 ...         ...
# 2095             641.0               350.0         6.7
# 2096             203.0               170.0         4.9
# 2097             105.0               192.0         6.5
# 2098              39.0                64.0         5.1
# 2099             553.0               445.0         7.7
#
# [2100 rows x 25 columns]

# %%
read_file=('Data/excel_Data_Movies.xls')
df_sheet3=pd.read_excel(read_file,
                        sheet_name='2010s',
                        names=list(df_sheet2.columns),
                       skiprows=2)
df_sheet3
# Out:
#                                      Title    Year  \
# 0                               127 Hours   2010.0
# 1                             3 Backyards   2010.0
# 2                                       3   2010.0
# 3               8: The Mormon Proposition   2010.0
# 4     A Turtle's Tale: Sammy's Adventures   2010.0
# ...                                    ...     ...
# 1599              War & Peace                  NaN
# 1600                    Wings                  NaN
# 1601               Wolf Creek                  NaN
# 1602        Wuthering Heights                  NaN
# 1603  Yu-Gi-Oh! Duel Monsters                  NaN
#
#                                          Genres  Language    Country  \
# 0            Adventure|Biography|Drama|Thriller   English        USA
# 1                                         Drama   English        USA
# 2                          Comedy|Drama|Romance    German    Germany
# 3                                   Documentary   English        USA
# 4                    Adventure|Animation|Family   English     France
# ...                                         ...       ...        ...
# 1599                  Drama|History|Romance|War   English         UK
# 1600                               Comedy|Drama   English        USA
# 1601                      Drama|Horror|Thriller   English  Australia
# 1602                              Drama|Romance   English         UK
# 1603  Action|Adventure|Animation|Family|Fantasy  Japanese      Japan
#
#      Content Rating  Duration  Aspect Ratio      Budget  Gross Earnings  ...  \
# 0                 R      94.0          1.85  18000000.0      18329466.0  ...
# 1                 R      88.0           NaN    300000.0             NaN  ...
# 2           Unrated     119.0          2.35         NaN         59774.0  ...
# 3                 R      80.0          1.78   2500000.0         99851.0  ...
# 4                PG      88.0          2.35         NaN             NaN  ...
# ...             ...       ...           ...         ...             ...  ...
# 1599          TV-14       NaN         16.00         NaN             NaN  ...
# 1600            NaN      30.0          1.33         NaN             NaN  ...
# 1601            NaN       NaN          2.00         NaN             NaN  ...
# 1602            NaN     142.0           NaN         NaN             NaN  ...
# 1603            NaN      24.0           NaN         NaN             NaN  ...
#
#      Facebook Likes - Actor 1 Facebook Likes - Actor 2  \
# 0                     11000.0                    642.0
# 1                       795.0                    659.0
# 2                        24.0                     20.0
# 3                       191.0                     12.0
# 4                       783.0                    749.0
# ...                       ...                      ...
# 1599                   1000.0                    888.0
# 1600                    685.0                    511.0
# 1601                    511.0                    457.0
# 1602                  27000.0                    698.0
# 1603                      0.0                      NaN
#
#      Facebook Likes - Actor 3 Facebook Likes - cast Total  \
# 0                       223.0                       11984
# 1                       301.0                        1884
# 2                         9.0                          69
# 3                         5.0                         210
# 4                       602.0                        3874
# ...                       ...                         ...
# 1599                    502.0                        4528
# 1600                    424.0                        1884
# 1601                    206.0                        1617
# 1602                    427.0                       29196
# 1603                      NaN                           0
#
#       Facebook likes - Movie  Facenumber in posters  User Votes  \
# 0                      63000                    0.0      279179
# 1                         92                    0.0         554
# 2                       2000                    0.0        4212
# 3                          0                    0.0        1138
# 4                          0                    2.0        5385
# ...                      ...                    ...         ...
# 1599                   11000                    1.0        9277
# 1600                    1000                    5.0        7646
# 1601                     954                    0.0         726
# 1602                       0                    2.0        6053
# 1603                     124                    0.0       12417
#
#       Reviews by Users  Reviews by Crtiics  IMDB Score
# 0                440.0               450.0         7.6
# 1                 23.0                20.0         5.2
# 2                 18.0                76.0         6.8
# 3                 30.0                28.0         7.1
# 4                 22.0                56.0         6.1
# ...                ...                 ...         ...
# 1599              44.0                10.0         8.2
# 1600              56.0                19.0         7.3
# 1601               6.0                 2.0         7.1
# 1602              33.0                 9.0         7.7
# 1603              51.0                 6.0         7.0
#
# [1604 rows x 25 columns]

# %% [markdown]
# ## THỰC HÀNH 3:
# ---
# **Mô tả file dữ liệu: Data_Patient.csv**
# * File dữ liệu chứa thông tin của 300 bệnh nhân bị chứng đau ngực
# * Mỗi dòng ứng với thông tin của một bệnh nhân, bao gồm 9 thuộc tính.
#
# **Chi tiết thông tin của một bệnh nhân như sau:**
# * id: Mã của bệnh nhân (số)
# * Feature_1: Tuổi của bệnh nhân (số)
# * Feature_2: Giới tính của bệnh nhân (chuỗi: Male – Female)
# * Feature_3: Cho biết loại triệu chứng đau ngực mà bệnh nhân này mắc phải, với 4 giá trị: (Typical angina, Atypical angina, Non-anginal pain, Asymptomatic)
# * Feature_4: Huyết áp của bệnh nhân – đơn vị: mmhg (số)
# * Feature_5: Chỉ số cholesterol của bệnh nhân – đơn vị: mg/dl (số)
# * Feature_6: Thông số nhịp tim của bệnh nhân – đơn vị: lần/phút (số)
# * Feature_7: Chỉ số Thalassemia của bệnh nhân chỉ gồm 3 giá trị (3: Bình thường | 4: Khiếm khuyết cố định | 7: Kiếm khuyết có thể đảo ngược)
# * Feature_8: Cho biết bệnh nhân có bị bệnh tim hay không? (0: Không bị bệnh tim mạch | 1: Bị bệnh tim mạch)

# %% [markdown]
# **Yêu cầu 3.1:**
# 1. Đọc dữ liệu từ file Data_Excercise\Data_patient.csv vào biến kiểu dataframe: df_patient với cột đầu tiên (id) là cột chỉ số (index_col)
# 2. Hiển thị thông tin tổng quan của tập dữ liệu
# 3. Hiển thị thông tin của 10 bệnh nhân đầu tiên và 5 bệnh nhân cuối cùng của tập dữ liệu.
# 4. Đặt lại tên các cột dữ liệu trong Dataframe:
#     * Feature_1 --> Age
#     * Feature_2 --> Gender
#     * Feature_3 --> Type
#     * Feature_4 --> Blood_pressure
#     * Feature_5 --> Cholesterol
#     * Feature_6 --> Heartbeat
#     * Feature_7 --> Thalassemia
#     * Feature_8 --> Result

# %%
#{VIẾT CODE CỦA BẠN VÀO ĐÂY}
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
# Cột đầu tiên (id) là cột chỉ số (index_col)
df_patient= pd.read_csv('Data/Data_Patient.csv', index_col=0)
df_patient
# Out:
#              feature_1 feature_2         feature_3  feature_4  feature_5  \
# id
# Patient_01          63      Male    Typical angina        145        233
# Patient_02          67      Male      Asymptomatic        160        286
# Patient_03          67      Male      Asymptomatic        120        229
# Patient_04          37      Male  Non-anginal pain        130        250
# Patient_05          41    Female   Atypical angina        130        204
# ...                ...       ...               ...        ...        ...
# Patient_296         59      Male      Asymptomatic        164        176
# Patient_297         57    Female      Asymptomatic        140        241
# Patient_298         45      Male    Typical angina        110        264
# Patient_299         68      Male      Asymptomatic        144        193
# Patient_300         57      Male      Asymptomatic        130        131
#
#              feature_6  feature_7  feature_8
# id
# Patient_01         150        6.0          0
# Patient_02         108        3.0          1
# Patient_03         129        7.0          1
# Patient_04         187        3.0          0
# Patient_05         172        NaN          0
# ...                ...        ...        ...
# Patient_296         90        6.0          1
# Patient_297        123        7.0          1
# Patient_298        132        7.0          1
# Patient_299        141        7.0          1
# Patient_300        115        7.0          1
#
# [300 rows x 8 columns]

# %%
# hiển thị thông tin tổng quan của nhập dữ liệu
df_patient.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 300 entries, Patient_01 to Patient_300
# Data columns (total 8 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   feature_1  300 non-null    int64
#  1   feature_2  300 non-null    object
#  2   feature_3  295 non-null    object
#  3   feature_4  300 non-null    int64
#  4   feature_5  300 non-null    int64
#  5   feature_6  300 non-null    int64
#  6   feature_7  293 non-null    float64
#  7   feature_8  300 non-null    int64
# dtypes: float64(1), int64(5), object(2)
# memory usage: 21.1+ KB

# %%
#Hiển thị thông tin của 10 bệnh nhân đầu tiên và 5 bệnh nhân cuối cùng của tập dữ liệu.
print("Thông tin của 10 bệnh nhân đầu tiên")
df_10_bnd=df_patient.iloc[:10,:]
df_10_bnd
# Out:
# Thông tin của 10 bệnh nhân đầu tiên
#             feature_1 feature_2         feature_3  feature_4  feature_5  \
# id
# Patient_01         63      Male    Typical angina        145        233
# Patient_02         67      Male      Asymptomatic        160        286
# Patient_03         67      Male      Asymptomatic        120        229
# Patient_04         37      Male  Non-anginal pain        130        250
# Patient_05         41    Female   Atypical angina        130        204
# Patient_06         56      Male   Atypical angina        120        236
# Patient_07         62    Female      Asymptomatic        140        268
# Patient_08         57    Female      Asymptomatic        120        354
# Patient_09         63      Male      Asymptomatic        130        254
# Patient_10         53      Male      Asymptomatic        140        203
#
#             feature_6  feature_7  feature_8
# id
# Patient_01        150        6.0          0
# Patient_02        108        3.0          1
# Patient_03        129        7.0          1
# Patient_04        187        3.0          0
# Patient_05        172        NaN          0
# Patient_06        178        3.0          0
# Patient_07        160        3.0          1
# Patient_08        163        3.0          0
# Patient_09        147        7.0          1
# Patient_10        155        7.0          1

# %%
print(" Thông tin của 5 bệnh nhân cuối cùng")
df_5bnc=df_patient.tail()
df_5bnc
# Out:
#  Thông tin của 5 bệnh nhân cuối cùng
#              feature_1 feature_2       feature_3  feature_4  feature_5  \
# id
# Patient_296         59      Male    Asymptomatic        164        176
# Patient_297         57    Female    Asymptomatic        140        241
# Patient_298         45      Male  Typical angina        110        264
# Patient_299         68      Male    Asymptomatic        144        193
# Patient_300         57      Male    Asymptomatic        130        131
#
#              feature_6  feature_7  feature_8
# id
# Patient_296         90        6.0          1
# Patient_297        123        7.0          1
# Patient_298        132        7.0          1
# Patient_299        141        7.0          1
# Patient_300        115        7.0          1

# %%
#Đặt lại tên các cột dữ liệu trong Dataframe
df_patient.rename(columns={'feature_1':'Age',
                 'feature_2':'Gender',
                 'feature_3':'Type',
                 'feature_4':'Blood_pressure',
                 'feature_5':'Cholesterol',
                 'feature_6':'Heartbeat',
                 'feature_7':'Thalassemia',
                 'feature_8':'Result'}, inplace=True)
df_patient
# Out:
#              Age  Gender              Type  Blood_pressure  Cholesterol  \
# id
# Patient_01    63    Male    Typical angina             145          233
# Patient_02    67    Male      Asymptomatic             160          286
# Patient_03    67    Male      Asymptomatic             120          229
# Patient_04    37    Male  Non-anginal pain             130          250
# Patient_05    41  Female   Atypical angina             130          204
# ...          ...     ...               ...             ...          ...
# Patient_296   59    Male      Asymptomatic             164          176
# Patient_297   57  Female      Asymptomatic             140          241
# Patient_298   45    Male    Typical angina             110          264
# Patient_299   68    Male      Asymptomatic             144          193
# Patient_300   57    Male      Asymptomatic             130          131
#
#              Heartbeat  Thalassemia  Result
# id
# Patient_01         150          6.0       0
# Patient_02         108          3.0       1
# Patient_03         129          7.0       1
# Patient_04         187          3.0       0
# Patient_05         172          NaN       0
# ...                ...          ...     ...
# Patient_296         90          6.0       1
# Patient_297        123          7.0       1
# Patient_298        132          7.0       1
# Patient_299        141          7.0       1
# Patient_300        115          7.0       1
#
# [300 rows x 8 columns]

# %% [markdown]
# **Yêu cầu 3.2:**
# Sử dụng phương thức .describe() cho biết:
#
#     * Thuộc tính Age:
#         - Tuổi của bệnh nhân trẻ nhất
#         - Tuổi của bệnh nhân già nhất
#     * Thuộc tính Cholesterol:
#         - Cholesterol trung bình của các bệnh nhân
#         - Độ lệch chuẩn của giá trị này trong toàn bộ tập dữ liệu
#     * Bao nhiêu bệnh nhân giới tính nam (Male)
#     * Có bao nhiêu giá trị khác nhau của thuộc tính Type. Giá trị xuất hiện nhiều nhất là giá trị nào, bao nhiêu lần.

# %%
#{VIẾT CODE CỦA BẠN VÀO ĐÂY}
""" Thuộc tính Age:
    - Tuổi của bệnh nhân trẻ nhất
    - Tuổi của bệnh nhân già nhất"""

df_patient[['Age']].describe()
# Out:
#               Age
# count  300.000000
# mean    54.490000
# std      9.032267
# min     29.000000
# 25%     48.000000
# 50%     56.000000
# 75%     61.000000
# max     77.000000

# %%
"""Thuộc tính Cholesterol:
    - Cholesterol trung bình của các bệnh nhân
    - Độ lệch chuẩn của giá trị này trong toàn bộ tập dữ liệu"""
df_patient[['Cholesterol']].describe()
# Out:
#        Cholesterol
# count   300.000000
# mean    247.070000
# std      51.835136
# min     126.000000
# 25%     211.000000
# 50%     242.500000
# 75%     275.250000
# max     564.000000

# %%
#Bao nhiêu bệnh nhân giới tính nam (Male)
df_patient[['Gender']].value_counts()
# Out:
# Gender
# Male      205
# Female     95
# dtype: int64

# %%
#Có bao nhiêu giá trị khác nhau của thuộc tính Type. Giá trị xuất hiện nhiều nhất là giá trị nào, bao nhiêu lần.
df_fine2=df_patient[['Type']].describe()
df_fine2
# Out:
#                 Type
# count            295
# unique             4
# top     Asymptomatic
# freq             139

# %%
df_patient.head()
# Out:
#             Age  Gender              Type  Blood_pressure  Cholesterol  \
# id
# Patient_01   63    Male    Typical angina             145          233
# Patient_02   67    Male      Asymptomatic             160          286
# Patient_03   67    Male      Asymptomatic             120          229
# Patient_04   37    Male  Non-anginal pain             130          250
# Patient_05   41  Female   Atypical angina             130          204
#
#             Heartbeat  Thalassemia  Result
# id
# Patient_01        150          6.0       0
# Patient_02        108          3.0       1
# Patient_03        129          7.0       1
# Patient_04        187          3.0       0
# Patient_05        172          NaN       0

# %% [markdown]
# **Yêu cầu 3.3:**
#
# Cho biết những cột nào trong dữ liệu có chứa missing data và số lượng missing là bao nhiêu?

# %%
#{VIẾT CODE CỦA BẠN VÀO ĐÂY}
#Cho biết những cột nào trong dữ liệu có chứa missing data
df_patient.isnull()
# Out:
#                Age  Gender   Type  Blood_pressure  Cholesterol  Heartbeat  \
# id
# Patient_01   False   False  False           False        False      False
# Patient_02   False   False  False           False        False      False
# Patient_03   False   False  False           False        False      False
# Patient_04   False   False  False           False        False      False
# Patient_05   False   False  False           False        False      False
# ...            ...     ...    ...             ...          ...        ...
# Patient_296  False   False  False           False        False      False
# Patient_297  False   False  False           False        False      False
# Patient_298  False   False  False           False        False      False
# Patient_299  False   False  False           False        False      False
# Patient_300  False   False  False           False        False      False
#
#              Thalassemia  Result
# id
# Patient_01         False   False
# Patient_02         False   False
# Patient_03         False   False
# Patient_04         False   False
# Patient_05          True   False
# ...                  ...     ...
# Patient_296        False   False
# Patient_297        False   False
# Patient_298        False   False
# Patient_299        False   False
# Patient_300        False   False
#
# [300 rows x 8 columns]

# %%
# Thống kê số lượng null
df_patient.isnull().sum()
# Out:
# Age               0
# Gender            0
# Type              5
# Blood_pressure    0
# Cholesterol       0
# Heartbeat         0
# Thalassemia       7
# Result            0
# dtype: int64

# %% [markdown]
# **Yêu cầu 3.4:**
# Hiển thị thông tin của các bệnh nhân:
#    * Bệnh nhân có index: Patient_100; Patient_150; Patient_200
#    * Bệnh nhân ở vị trí 255 đến 260, với 3 thuộc tính: Age, Gender và Result

# %%
#{VIẾT CODE CỦA BẠN VÀO ĐÂY}

# Hiển thị thông tin của các bệnh nhân:

# Bệnh nhân có index: Patient_100; Patient_150; Patient_200
df_patient.loc[['Patient_100','Patient_150','Patient_200'],:]
# Out:
#              Age  Gender            Type  Blood_pressure  Cholesterol  \
# id
# Patient_100   45    Male    Asymptomatic             115          260
# Patient_150   52    Male  Typical angina             152          298
# Patient_200   50  Female    Asymptomatic             110          254
#
#              Heartbeat  Thalassemia  Result
# id
# Patient_100        185          3.0       0
# Patient_150        178          7.0       0
# Patient_200        159          3.0       0

# %%
#Bệnh nhân ở vị trí 255 đến 260, với 3 thuộc tính: Age, Gender và Result
df_patient.loc[['Patient_255','Patient_256','Patient_257','Patient_258','Patient_259','Patient_260'],['Age','Gender','Result']]
# Out:
#              Age  Gender  Result
# id
# Patient_255   42  Female       0
# Patient_256   67  Female       0
# Patient_257   76  Female       0
# Patient_258   70    Male       0
# Patient_259   57    Male       1
# Patient_260   44  Female       0

# %%
df=pd.read_csv('Data/Data_Patient.csv')
df.rename(columns={'feature_1':'Age',
                 'feature_2':'Gender',
                 'feature_3':'Type',
                 'feature_4':'Blood_pressure',
                 'feature_5':'Cholesterol',
                 'feature_6':'Heartbeat',
                 'feature_7':'Thalassemia',
                 'feature_8':'Result'}, inplace=True)
df.loc[255:260,['Age','Gender','Result']]
# Out:
#      Age  Gender  Result
# 255   67  Female       0
# 256   76  Female       0
# 257   70    Male       0
# 258   57    Male       1
# 259   44  Female       0
# 260   58  Female       1

# %% [markdown]
# **Yêu cầu 3.5:**
# 1. Thay đổi giá trị cho thuộc tính Gender: Male --> 0, Female --> 1
# 2. Thay đổi giá trị cho thuộc tính Result: 0 --> No, 1 --> Yes
# 3. Cập nhật giá trị thuộc tính Thalassemia của bệnh nhân có index: Patient_05 bằng giá trị 4.0

# %%
#{VIẾT CODE CỦA BẠN VÀO ĐÂY

#Thay đổi giá trị cho thuộc tính Gender: Male --> 0, Female --> 1
change_gender={'Male':0,
             'Female':1}
df['Gender'].replace(change_gender,inplace=True)
df

#Thay đổi giá trị cho thuộc tính Result: 0-->no, 1-->yes
df['Result'].replace({0:'No',
                     1:'Yes'},inplace=True)
df
# Out:
#               id  Age  Gender              Type  Blood_pressure  Cholesterol  \
# 0     Patient_01   63       0    Typical angina             145          233
# 1     Patient_02   67       0      Asymptomatic             160          286
# 2     Patient_03   67       0      Asymptomatic             120          229
# 3     Patient_04   37       0  Non-anginal pain             130          250
# 4     Patient_05   41       1   Atypical angina             130          204
# ..           ...  ...     ...               ...             ...          ...
# 295  Patient_296   59       0      Asymptomatic             164          176
# 296  Patient_297   57       1      Asymptomatic             140          241
# 297  Patient_298   45       0    Typical angina             110          264
# 298  Patient_299   68       0      Asymptomatic             144          193
# 299  Patient_300   57       0      Asymptomatic             130          131
#
#      Heartbeat  Thalassemia Result
# 0          150          6.0     No
# 1          108          3.0    Yes
# 2          129          7.0    Yes
# 3          187          3.0     No
# 4          172          NaN     No
# ..         ...          ...    ...
# 295         90          6.0    Yes
# 296        123          7.0    Yes
# 297        132          7.0    Yes
# 298        141          7.0    Yes
# 299        115          7.0    Yes
#
# [300 rows x 9 columns]

# %%
#Cập nhật giá trị thuộc tính Thalassemia của bệnh nhân có index: Patient_05 bằng giá trị 4.0
df_patient.loc[['Patient_05'],['Thalassemia']]=4.0
df_patient

# %% [markdown]
# # THỰC HÀNH 4:
# ---
# **Yêu cầu 4.1:**
# 1. Đọc dữ liệu từ file Data_Excercise\Data_patient.csv vào biến kiểu dataframe: df_patient với cột feature_1 là cột chỉ số (index_col)
# 2. Đặt lại tên các cột dữ liệu trong Dataframe:
#     * Feature_1 --> Age
#     * Feature_2 --> Gender
#     * Feature_3 --> Type
#     * Feature_4 --> Blood_pressure
#     * Feature_5 --> Cholesterol
#     * Feature_6 --> Heartbeat
#     * Feature_7 --> Thalassemia
#     * Feature_8 --> Result
#
#  *Như yêu cầu đã thực hiện trong bài thực hành số 3*

# %%
#{HỌC VIÊN VIẾT CODE VÀO ĐÂY}
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

#df_patient với cột feature_1 là cột chỉ số (index_col)
df_patient=pd.read_csv('Data/Data_patient.csv', index_col=0)
df_patient
# Out:
#              feature_1 feature_2         feature_3  feature_4  feature_5  \
# id
# Patient_01          63      Male    Typical angina        145        233
# Patient_02          67      Male      Asymptomatic        160        286
# Patient_03          67      Male      Asymptomatic        120        229
# Patient_04          37      Male  Non-anginal pain        130        250
# Patient_05          41    Female   Atypical angina        130        204
# ...                ...       ...               ...        ...        ...
# Patient_296         59      Male      Asymptomatic        164        176
# Patient_297         57    Female      Asymptomatic        140        241
# Patient_298         45      Male    Typical angina        110        264
# Patient_299         68      Male      Asymptomatic        144        193
# Patient_300         57      Male      Asymptomatic        130        131
#
#              feature_6  feature_7  feature_8
# id
# Patient_01         150        6.0          0
# Patient_02         108        3.0          1
# Patient_03         129        7.0          1
# Patient_04         187        3.0          0
# Patient_05         172        NaN          0
# ...                ...        ...        ...
# Patient_296         90        6.0          1
# Patient_297        123        7.0          1
# Patient_298        132        7.0          1
# Patient_299        141        7.0          1
# Patient_300        115        7.0          1
#
# [300 rows x 8 columns]

# %%
"""Đặt lại tên các cột dữ liệu trong Dataframe:

Feature_1 --> Age
Feature_2 --> Gender
Feature_3 --> Type
Feature_4 --> Blood_pressure
Feature_5 --> Cholesterol
Feature_6 --> Heartbeat
Feature_7 --> Thalassemia
Feature_8 --> Result"""
change_name={'feature_1':'Age',
             'feature_2':'Gender',
             'feature_3':'Type',
             'feature_4':'Blood_pressure',
             'feature_5':'Cholesterol',
             'feature_6':'Heartbeat',
             'feature_7':'Thalassemia',
             'feature_8':'Result'}        
df_patient2=df_patient.rename(columns=change_name)
df_patient2
# Out:
#              Age  Gender              Type  Blood_pressure  Cholesterol  \
# id
# Patient_01    63    Male    Typical angina             145          233
# Patient_02    67    Male      Asymptomatic             160          286
# Patient_03    67    Male      Asymptomatic             120          229
# Patient_04    37    Male  Non-anginal pain             130          250
# Patient_05    41  Female   Atypical angina             130          204
# ...          ...     ...               ...             ...          ...
# Patient_296   59    Male      Asymptomatic             164          176
# Patient_297   57  Female      Asymptomatic             140          241
# Patient_298   45    Male    Typical angina             110          264
# Patient_299   68    Male      Asymptomatic             144          193
# Patient_300   57    Male      Asymptomatic             130          131
#
#              Heartbeat  Thalassemia  Result
# id
# Patient_01         150          6.0       0
# Patient_02         108          3.0       1
# Patient_03         129          7.0       1
# Patient_04         187          3.0       0
# Patient_05         172          NaN       0
# ...                ...          ...     ...
# Patient_296         90          6.0       1
# Patient_297        123          7.0       1
# Patient_298        132          7.0       1
# Patient_299        141          7.0       1
# Patient_300        115          7.0       1
#
# [300 rows x 8 columns]

# %% [markdown]
# **Yêu cầu 4.2:**
# Lọc dữ liệu trong df_patient thành các DataFrame:
#     * df_male: chứa danh sách bệnh nhân Nam
#     * df_female: chứa danh sách bệnh nhân nữ
#     * df_no: danh sách những người không bị bệnh đau tim
#     * df_yes: danh sách những người bị bệnh đau tim

# %%
#{HỌC VIÊN VIẾT CODE VÀO ĐÂY}
#Lọc dữ liệu trong df_patient thành các DataFrame: * df_male: chứa danh sách bệnh nhân Nam 
df_male=df_patient2[df_patient2['Gender'] == 'Male']
df_male
# Out:
#              Age Gender              Type  Blood_pressure  Cholesterol  \
# id
# Patient_01    63   Male    Typical angina             145          233
# Patient_02    67   Male      Asymptomatic             160          286
# Patient_03    67   Male      Asymptomatic             120          229
# Patient_04    37   Male  Non-anginal pain             130          250
# Patient_06    56   Male   Atypical angina             120          236
# ...          ...    ...               ...             ...          ...
# Patient_295   41   Male   Atypical angina             120          157
# Patient_296   59   Male      Asymptomatic             164          176
# Patient_298   45   Male    Typical angina             110          264
# Patient_299   68   Male      Asymptomatic             144          193
# Patient_300   57   Male      Asymptomatic             130          131
#
#              Heartbeat  Thalassemia  Result
# id
# Patient_01         150          6.0       0
# Patient_02         108          3.0       1
# Patient_03         129          7.0       1
# Patient_04         187          3.0       0
# Patient_06         178          3.0       0
# ...                ...          ...     ...
# Patient_295        182          3.0       0
# Patient_296         90          6.0       1
# Patient_298        132          7.0       1
# Patient_299        141          7.0       1
# Patient_300        115          7.0       1
#
# [205 rows x 8 columns]

# %%
#Lọc dữ liệu trong df_patient thành các DataFrame df_female: chứa danh sách bệnh nhân nữ
df_female=df_patient2[df_patient2['Gender']=='Female']
df_female
# Out:
#              Age  Gender              Type  Blood_pressure  Cholesterol  \
# id
# Patient_05    41  Female   Atypical angina             130          204
# Patient_07    62  Female      Asymptomatic             140          268
# Patient_08    57  Female      Asymptomatic             120          354
# Patient_12    56  Female   Atypical angina             140          294
# Patient_19    48  Female  Non-anginal pain             130          275
# ...          ...     ...               ...             ...          ...
# Patient_282   55  Female      Asymptomatic             128          205
# Patient_286   58  Female      Asymptomatic             170          225
# Patient_291   55  Female   Atypical angina             132          342
# Patient_294   63  Female      Asymptomatic             124          197
# Patient_297   57  Female      Asymptomatic             140          241
#
#              Heartbeat  Thalassemia  Result
# id
# Patient_05         172          NaN       0
# Patient_07         160          3.0       1
# Patient_08         163          3.0       0
# Patient_12         153          3.0       0
# Patient_19         139          3.0       0
# ...                ...          ...     ...
# Patient_282        130          7.0       1
# Patient_286        146          6.0       1
# Patient_291        166          3.0       0
# Patient_294        136          NaN       1
# Patient_297        123          7.0       1
#
# [95 rows x 8 columns]

# %%
# Lọc dữ liệu trong df_patient thành các DataFrame df_no: danh sách những người không bị bệnh đau tim
df_no=df[df['Result']=='No']
df_no
# Out:
#               id  Age  Gender              Type  Blood_pressure  Cholesterol  \
# 0     Patient_01   63       0    Typical angina             145          233
# 3     Patient_04   37       0  Non-anginal pain             130          250
# 4     Patient_05   41       1   Atypical angina             130          204
# 5     Patient_06   56       0   Atypical angina             120          236
# 7     Patient_08   57       1      Asymptomatic             120          354
# ..           ...  ...     ...               ...             ...          ...
# 286  Patient_287   58       0   Atypical angina             125          220
# 287  Patient_288   56       0   Atypical angina             130          221
# 288  Patient_289   56       0   Atypical angina             120          240
# 290  Patient_291   55       1   Atypical angina             132          342
# 294  Patient_295   41       0   Atypical angina             120          157
#
#      Heartbeat  Thalassemia Result
# 0          150          6.0     No
# 3          187          3.0     No
# 4          172          NaN     No
# 5          178          3.0     No
# 7          163          3.0     No
# ..         ...          ...    ...
# 286        144          7.0     No
# 287        163          7.0     No
# 288        169          3.0     No
# 290        166          3.0     No
# 294        182          3.0     No
#
# [162 rows x 9 columns]

# %%
#Lọc dữ liệu trong df_patient thành các DataFrame df_yes: danh sách những người bị bệnh đau tim
df_yes=df[df['Result']=='Yes']
df_yes
# Out:
#               id  Age  Gender            Type  Blood_pressure  Cholesterol  \
# 1     Patient_02   67       0    Asymptomatic             160          286
# 2     Patient_03   67       0    Asymptomatic             120          229
# 6     Patient_07   62       1    Asymptomatic             140          268
# 8     Patient_09   63       0    Asymptomatic             130          254
# 9     Patient_10   53       0    Asymptomatic             140          203
# ..           ...  ...     ...             ...             ...          ...
# 295  Patient_296   59       0    Asymptomatic             164          176
# 296  Patient_297   57       1    Asymptomatic             140          241
# 297  Patient_298   45       0  Typical angina             110          264
# 298  Patient_299   68       0    Asymptomatic             144          193
# 299  Patient_300   57       0    Asymptomatic             130          131
#
#      Heartbeat  Thalassemia Result
# 1          108          3.0    Yes
# 2          129          7.0    Yes
# 6          160          3.0    Yes
# 8          147          7.0    Yes
# 9          155          7.0    Yes
# ..         ...          ...    ...
# 295         90          6.0    Yes
# 296        123          7.0    Yes
# 297        132          7.0    Yes
# 298        141          7.0    Yes
# 299        115          7.0    Yes
#
# [138 rows x 9 columns]

# %% [markdown]
# **Yêu cầu 4.3:**
# Lọc trong df_patient dưa ra danh sách bệnh nhân thỏa mãn yêu cầu sau:
# 1. Những người bị mắc bệnh đau tim và trên 70 tuổi
# 2. Người có giới tính Female, có huyết áp trên 170 mmhg nhưng không bị bệnh đau tim.
# 3. Những người có triệu chứng đau ngực là Typical angina, giới tính Male và bị bệnh đau tim.

# %%
#{HỌC VIÊN VIẾT CODE VÀO ĐÂY}
#Những người bị mắc bệnh đau tim và trên 70 tuổi
df_1= df[(df['Age']>=70) & (df['Result']=='Yes')]
df_1
# Out:
#               id  Age  Gender              Type  Blood_pressure  Cholesterol  \
# 135  Patient_136   70       0      Asymptomatic             145          174
# 154  Patient_155   70       0      Asymptomatic             130          322
# 160  Patient_161   77       0      Asymptomatic             125          304
# 169  Patient_170   70       0  Non-anginal pain             160          269
#
#      Heartbeat  Thalassemia Result
# 135        125          7.0    Yes
# 154        109          3.0    Yes
# 160        162          3.0    Yes
# 169        112          7.0    Yes

# %%
# Người có giới tính Female, có huyết áp trên 170 mmhg nhưng không bị bệnh đau tim.
df_2=df_patient[(df_patient['feature_2']=='Female')&(df_patient['feature_4']>=170)&(df_patient['feature_8']==1)]
df_2
# Out:
#              feature_1 feature_2     feature_3  feature_4  feature_5  \
# id
# Patient_126         56    Female  Asymptomatic        200        288
# Patient_172         59    Female  Asymptomatic        174        249
# Patient_213         66    Female  Asymptomatic        178        228
# Patient_231         55    Female  Asymptomatic        180        327
# Patient_286         58    Female  Asymptomatic        170        225
#
#              feature_6  feature_7  feature_8
# id
# Patient_126        133        7.0          1
# Patient_172        143        3.0          1
# Patient_213        165        7.0          1
# Patient_231        117        3.0          1
# Patient_286        146        6.0          1

# %%
# Những người có triệu chứng đau ngực là Typical angina, giới tính Male và bị bệnh đau tim
df_3=df_patient[(df_patient['feature_3']=='Typical angina')&(df_patient['feature_2']=='Male')&(df_patient['feature_8']==1)]
df_3
# Out:
#              feature_1 feature_2       feature_3  feature_4  feature_5  \
# id
# Patient_124         65      Male  Typical angina        138        282
# Patient_141         59      Male  Typical angina        170        288
# Patient_199         59      Male  Typical angina        160        273
# Patient_211         38      Male  Typical angina        120        231
# Patient_243         61      Male  Typical angina        134        234
# Patient_274         59      Male  Typical angina        134        204
# Patient_298         45      Male  Typical angina        110        264
#
#              feature_6  feature_7  feature_8
# id
# Patient_124        174        3.0          1
# Patient_141        159        7.0          1
# Patient_199        125        3.0          1
# Patient_211        182        7.0          1
# Patient_243        145        3.0          1
# Patient_274        162        3.0          1
# Patient_298        132        7.0          1

# %% [markdown]
# **Yêu cầu 4.4:** Xác định:
# 1. Chỉ số huyết áp (Blood_pressure) thấp nhất, cao nhất, trung bình, trung vị và độ lệch chuẩn của tập dữ liệu
# 2. Chỉ số nhịp tim (Heartbeat) thấp nhất, cao nhất, trung bình, trung vị và độ lệch chuẩn của tập dữ liệu

# %%
#{HỌC VIEN VIẾT CODE VÀO ĐÂY}
#Chỉ số huyết áp (Blood_pressure) thấp nhất, cao nhất, trung bình, trung vị và độ lệch chuẩn của tập dữ liệu
print('Chỉ số huyết áp (Blood_pressure) thấp nhất, cao nhất, trung bình, trung vị và độ lệch chuẩn của tập dữ liệu')
df_441=df['Blood_pressure'].describe(include='all')
df_441
# Out:
# Chỉ số huyết áp (Blood_pressure) thấp nhất, cao nhất, trung bình, trung vị và độ lệch chuẩn của tập dữ liệu
# count    300.000000
# mean     131.686667
# std       17.682498
# min       94.000000
# 25%      120.000000
# 50%      130.000000
# 75%      140.000000
# max      200.000000
# Name: Blood_pressure, dtype: float64

# %%
#Chỉ số nhịp tim (Heartbeat) thấp nhất, cao nhất, trung bình, trung vị và độ lệch chuẩn của tập dữ liệu
print('Chỉ số nhịp tim (Heartbeat) thấp nhất, cao nhất, trung bình, trung vị và độ lệch chuẩn của tập dữ liệu')
df_442=df_patient['feature_6'].describe(include='all')
df_442
# Out:
# Chỉ số nhịp tim (Heartbeat) thấp nhất, cao nhất, trung bình, trung vị và độ lệch chuẩn của tập dữ liệu
# count    300.000000
# mean     149.563333
# std       22.818595
# min       71.000000
# 25%      133.750000
# 50%      152.500000
# 75%      165.250000
# max      202.000000
# Name: feature_6, dtype: float64

# %% [markdown]
# **Yêu cầu 4.5: Xác định:**
# 1. Số giá trị khác nhau của thuộc tính Type
# 2. Vẽ đồ thị dạng cột thể hiện kết quả thống kê số lượng theo từng giá trị khác nhau của thuộc tính Type

# %%
df.head()
# Out:
#            id  Age  Gender              Type  Blood_pressure  Cholesterol  \
# 0  Patient_01   63       0    Typical angina             145          233
# 1  Patient_02   67       0      Asymptomatic             160          286
# 2  Patient_03   67       0      Asymptomatic             120          229
# 3  Patient_04   37       0  Non-anginal pain             130          250
# 4  Patient_05   41       1   Atypical angina             130          204
#
#    Heartbeat  Thalassemia Result
# 0        150          6.0     No
# 1        108          3.0    Yes
# 2        129          7.0    Yes
# 3        187          3.0     No
# 4        172          NaN     No

# %%
#{HỌC VIÊN VIẾT CODE VÀO ĐÂY}
#Số giá trị khác nhau của thuộc tính Type
df_451=df['Type'].unique()
print(df_451)
# Out:
# ['Typical angina' 'Asymptomatic' 'Non-anginal pain' 'Atypical angina' nan]

# %%
# thống kê số lượng theo từng giá trị duy nhất
unique_type = df['Type'].value_counts()

# Vẽ đồ thị dạng cột thể hiện kết quả thống kê số lượng theo từng giá trị khác nhau của thuộc tính Type
plt.pie(unique_type.values,# lấy gtri
       labels=unique_type.index,# hiển thị nhãn
       autopct='0.2f'# hiển thị tỷ lệ
       )
# Out:
# ([<matplotlib.patches.Wedge at 0x26a6b279460>,
#   <matplotlib.patches.Wedge at 0x26a6b279bb0>,
#   <matplotlib.patches.Wedge at 0x26a6b282310>,
#   <matplotlib.patches.Wedge at 0x26a6b282a30>],
#  [Text(0.09943662579624836, 1.0954963977349523, 'Asymptomatic'),
#   Text(-0.8316732042866889, -0.7199442209445892, 'Non-anginal pain'),
#   Text(0.5834628716696572, -0.9325079503055174, 'Atypical angina'),
#   Text(1.0671676318930072, -0.2667456568341296, 'Typical angina')],
#  [Text(0.05423815952522637, 0.5975434896736104, '0.2f'),
#   Text(-0.45363992961092114, -0.3926968477879577, '0.2f'),
#   Text(0.31825247545617663, -0.5086407001666458, '0.2f'),
#   Text(0.5820914355780039, -0.1454976310004343, '0.2f')])
